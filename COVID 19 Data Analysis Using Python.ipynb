# %% [markdown]
# # Module Imports

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing COVID Dataset

# %%
corona_dataset_csv = pd.read_csv('covid19_confirmed_global.csv')
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                           NaN            Argentina -38.41610  -63.616700
# 7                           NaN              Armenia  40.06910   45.038200
# 8  Australian Capital Territory            Australia -35.47350  149.012400
# 9               New South Wales            Australia -33.86880  151.209300
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  10/13/20  \
# ...

# %%
datas = corona_dataset_csv.rename(columns={'10/22/20' : 'Confirmed cases'})


df = datas[['Country/Region' , 'Confirmed cases']]
df.head(10)
# Out:
#         Country/Region  Confirmed cases
# 0          Afghanistan            40626
# 1              Albania            18250
# 2              Algeria            55357
# 3              Andorra             3811
# 4               Angola             8582
# 5  Antigua and Barbuda              122
# 6            Argentina          1053650
# 7              Armenia            70836
# 8            Australia              114
# 9            Australia             4370

# %%
corona_dataset_csv.shape
# Out:
# (267, 279)

# %%
corona_dataset_csv.drop(['Lat','Long'],axis=1,inplace=True)
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()
corona_dataset_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  10/13/20  \
# Country/Region                                           ...
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (189, 275)

# %%
datas = corona_dataset_aggregated.rename(columns={'10/22/20' : 'Confirmed cases'})
datas.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  10/13/20  10/14/20  10/15/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     39928     39994     40026
# Albania               0        0        0  ...     15752     15955     16212
# Algeria               0        0        0  ...     53399     53584     53777
# Andorra               0        0        0  ...      2995      3190      3190
# ...

# %% [markdown]
# # Visualizing data related to a country

# %%
corona_dataset_aggregated.loc['Iran'].plot()
corona_dataset_aggregated.loc['Pakistan'].plot()
corona_dataset_aggregated.loc['Turkey'].plot()
corona_dataset_aggregated.loc['South Africa'].plot()
corona_dataset_aggregated.loc['Italy'].plot()

plt.legend()

# %% [markdown]
# # Calculatin good measure

# %%
corona_dataset_aggregated.loc['Pakistan'].plot()
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %% [markdown]
# # Calculating First Derivative

# %%
corona_dataset_aggregated.loc['Pakistan'].diff().plot()

# %% [markdown]
# # Maximum Infection Rate Calculation

# %%
corona_dataset_aggregated.loc['Pakistan'].diff().max()
# Out:
# 12073.0

# %%
corona_dataset_aggregated.loc['Iran'].diff().max()
# Out:
# 5616.0

# %%
corona_dataset_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc['South Africa'].diff().max()
# Out:
# 13944.0

# %%
corona_dataset_aggregated.loc['Turkey'].diff().max()
# Out:
# 5138.0

# %% [markdown]
# #  Calculate maximum infection rate for all of the countries.

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
confirmed_cases = corona_dataset_aggregated.columns['10/22/20']
for country in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[country].diff().max())
corona_dataset_aggregated['Maximum Infection Rate'] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  10/15/20  10/16/20  10/17/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     40026     40073     40141
# Albania               0        0        0  ...     16212     16501     16774
# Algeria               0        0        0  ...     53777     53998     54203
# Andorra               0        0        0  ...      3190      3377      3377
# ...

# %% [markdown]
# # Create a new data frame

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated['Maximum Infection Rate'])
corona_data.head(10)
# Out:
#                      Maximum Infection Rate
# Country/Region
# Afghanistan                           915.0
# Albania                               302.0
# Algeria                               675.0
# Andorra                               299.0
# Angola                                289.0
# Antigua and Barbuda                    39.0
# Argentina                           18326.0
# Armenia                              2306.0
# Australia                             716.0
# Austria                              2435.0

# %% [markdown]
# # Importing World Happiness Report dataset

# %%
world_happiness_report = pd.read_csv("world_happiness_report_2020.csv")
world_happiness_report.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
world_happiness_report.shape
# Out:
# (153, 20)

# %%
columns_to_dropped = ['Generosity','Perceptions of corruption', 'Regional indicator', 'upperwhisker', 'lowerwhisker', 'Ladder score', 'Standard error of ladder score']
world_happiness_report.drop(columns_to_dropped,axis=1 , inplace=True)

# %%
world_happiness_report.head()
# Out:
#   Country name  Logged GDP per capita  Social support  \
# 0      Finland              10.639267        0.954330
# 1      Denmark              10.774001        0.955991
# 2  Switzerland              10.979933        0.942847
# 3      Iceland              10.772559        0.974670
# 4       Norway              11.087804        0.952487
#
#    Healthy life expectancy  Freedom to make life choices  \
# 0                71.900825                      0.949172
# 1                72.402504                      0.951444
# 2                74.102448                      0.921337
# 3                73.000000                      0.948892
# 4                73.200783                      0.955750
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                  1.972317                          1.285190
# 1                  1.972317                          1.326949
# 2                  1.972317                          1.390774
# ...

# %%
columns_to_dropped = ['Ladder score in Dystopia','Explained by: Log GDP per capita', 'Explained by: Social support', 'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices', 'Explained by: Generosity', 'Explained by: Perceptions of corruption', 'Dystopia + residual']
world_happiness_report.drop(columns_to_dropped,axis=1 , inplace=True)

# %%
world_happiness_report.set_index(['Country name'],inplace=True)
world_happiness_report.head()
# Out:
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Finland                   10.639267        0.954330                71.900825
# Denmark                   10.774001        0.955991                72.402504
# Switzerland               10.979933        0.942847                74.102448
# Iceland                   10.772559        0.974670                73.000000
# Norway                    11.087804        0.952487                73.200783
#
#               Freedom to make life choices
# Country name
# Finland                           0.949172
# Denmark                           0.951444
# Switzerland                       0.921337
# Iceland                           0.948892
# Norway                            0.955750

# %%
dataset = world_happiness_report.join(corona_data).copy()
dataset.head()
# Out:
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Finland                   10.639267        0.954330                71.900825
# Denmark                   10.774001        0.955991                72.402504
# Switzerland               10.979933        0.942847                74.102448
# Iceland                   10.772559        0.974670                73.000000
# Norway                    11.087804        0.952487                73.200783
#
#               Freedom to make life choices  Maximum Infection Rate
# Country name
# Finland                           0.949172                   296.0
# Denmark                           0.951444                   823.0
# Switzerland                       0.921337                  8737.0
# Iceland                           0.948892                   106.0
# Norway                            0.955750                   386.0

# %%
dataset.corr()
# it is representing the correlation between every two columns of our dataset
# Out:
#                               Logged GDP per capita  Social support  \
# Logged GDP per capita                      1.000000        0.781814
# Social support                             0.781814        1.000000
# Healthy life expectancy                    0.848469        0.742744
# Freedom to make life choices               0.419019        0.478863
# Maximum Infection Rate                     0.171897        0.097093
#
#                               Healthy life expectancy  \
# Logged GDP per capita                        0.848469
# Social support                               0.742744
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.448846
# Maximum Infection Rate                       0.178951
#
#                               Freedom to make life choices  \
# Logged GDP per capita                             0.419019
# Social support                                    0.478863
# ...

# %%
x = dataset['Logged GDP per capita']
y = dataset['Maximum Infection Rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
x = dataset['Healthy life expectancy']
y = dataset['Maximum Infection Rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
x = dataset['Social support']
y = dataset['Maximum Infection Rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
x = dataset['Freedom to make life choices']
y = dataset['Maximum Infection Rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))
